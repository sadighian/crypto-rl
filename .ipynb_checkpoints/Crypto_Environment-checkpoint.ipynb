# %%
from simulator import Simulator
from coinbase_connector.coinbase_orderbook import CoinbaseOrderBook
from bitfinex_connector.bitfinex_orderbook import BitfinexOrderBook

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
sim = Simulator()
scaler = StandardScaler()
# Out:
# Attempting to connect to Arctic...
# Connected to Arctic.

# %%
query = dict({
    'ccy': ['BCH-USD', 'tBCHUSD'],
    'start_date': 20181104,
    'end_date': 20181106
})

# tick_history = sim.get_tick_history(query)
# data = sim.get_orderbook_snapshot_history(CoinbaseOrderBook(query['ccy'][0]),
#                                                        BitfinexOrderBook(query['ccy'][1]),
#                                                        tick_history)  # historical data

normalized_data = sim.get_orderbook_snapshot_history_normalized(query=query, lags=3)
# Out:
# Getting ['BCH-USD', 'tBCHUSD'] tick data from Arctic Tick Store...
# c:\program files\python36\lib\site-packages\arctic\tickstore\tickstore.py:413: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(dtype, int):
# Completed querying 4000000 ['BCH-USD', 'tBCHUSD'] records in 10 seconds
#
# Splitting 4000000 records into 12 chunks... 333333 records/cpu
# Complete splitting pandas into chunks in 1 seconds.
# ***
# Completed get_tick_history() in 41 seconds
# ***
# Starting get_orderbook_snapshot_history() with 4000000 ticks for BCH-USD and tBCHUSD
# sequence gap: BCH-USD missing 7039195993 messages. new_sequence: 7039195993 [load_book]
#
# --Cleared BCH-USD order book--
# --Cleared tBCHUSD order book--
# BCH-USD first tick: 2018-11-04 15:22:41.685000+00:00 | Sequence: 7039195993
# ...completed 150000 loops in 5 seconds
# ...

# %%
data = pd.DataFrame(normalized_data, 
                    columns=sim.get_feature_labels(False))

# %%
data.head()
# Out:
#    coinbase_midpoint  midpoint_delta  coinbase-bid-notional-0  \
# 0           0.435936       -0.432372                 2.296043
# 1           0.435936       -0.432372                 2.296043
# 2           0.437840       -0.417439                 2.296043
# 3          -1.522311      -16.089545                 0.449376
# 4          -1.522311      -16.089545                 0.449376
#
#    coinbase-bid-notional-1  coinbase-bid-notional-2  coinbase-bid-notional-3  \
# 0                 1.541687                 1.207863                 1.061990
# 1                 1.541687                 1.207863                 1.061990
# 2                 1.541687                 1.207863                 1.061990
# 3                 0.485443                 0.260262                 0.202211
# 4                 0.485443                 0.260262                 0.202211
#
#    coinbase-bid-notional-4  coinbase-bid-notional-5  coinbase-bid-notional-6  \
# ...

# %%
columns = data.columns.tolist()

len(columns)
# Out:
# 126

# %%
lags = 3


if lags > 0:
    for lag in range(1, lags+1):
        for col in columns:
            data[('%s-%i' % (col, lag))] = data[col].shift(-lag)

# %%
data.columns.tolist()
# Out:
# ['coinbase_midpoint',
#  'midpoint_delta',
#  'coinbase-bid-notional-0',
#  'coinbase-bid-notional-1',
#  'coinbase-bid-notional-2',
#  'coinbase-bid-notional-3',
#  'coinbase-bid-notional-4',
#  'coinbase-bid-notional-5',
#  'coinbase-bid-notional-6',
#  'coinbase-bid-notional-7',
#  'coinbase-bid-notional-8',
#  'coinbase-bid-notional-9',
#  'coinbase-bid-notional-10',
#  'coinbase-bid-notional-11',
#  'coinbase-bid-notional-12',
#  'coinbase-bid-notional-13',
#  'coinbase-bid-notional-14',
#  'coinbase-bid-distance-0',
#  'coinbase-bid-distance-1',
#  'coinbase-bid-distance-2',
#  'coinbase-bid-distance-3',
#  'coinbase-bid-distance-4',
#  'coinbase-bid-distance-5',
#  'coinbase-bid-distance-6',
#  'coinbase-bid-distance-7',
#  'coinbase-bid-distance-8',
#  'coinbase-bid-distance-9',
#  'coinbase-bid-distance-10',
#  'coinbase-bid-distance-11',
#  'coinbase-bid-distance-12',
#  'coinbase-bid-distance-13',
#  'coinbase-bid-distance-14',
#  'coinbase-ask-notional-0',
# ...

# %%
len(sim.get_feature_labels(False, lags=2))
# Out:
# 378

# %%
data.shape
# Out:
# (38265, 362)

# %%
for lag in range(lags+1):
    print(lag)
# Out:
# 0
# 1
# 2
# 3

# %%
sim.export_normalized_data_to_csv(data_transformed=data)
# Out:
# Exported normalized order book snapshots to csv in 6 seconds
