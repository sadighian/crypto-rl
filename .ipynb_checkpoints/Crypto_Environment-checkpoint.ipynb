# %%
from simulator import Simulator
from coinbase_connector.coinbase_orderbook import CoinbaseOrderBook
from bitfinex_connector.bitfinex_orderbook import BitfinexOrderBook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# from arctic import Arctic, TICK_STORE
# from configurations.configs import MONGO_ENDPOINT, ARCTIC_NAME

# %%
sim = Simulator()
# Out:
# Attempting to connect to Arctic...
# Connected to Arctic.

# %%
# arctic = Arctic(MONGO_ENDPOINT)
# arctic.initialize_library(ARCTIC_NAME, lib_type=TICK_STORE)
# library = arctic[ARCTIC_NAME]

# %%
# library

# %%
query = {
    'ccy': ['LTC-USD', 'tLTCUSD'],
    'start_date': 20181120,
    'end_date': 20181122
}

tick_history = sim.get_tick_history(query)
# Out:
# Getting ['LTC-USD', 'tLTCUSD'] tick data from Arctic Tick Store...
# /home/jonathan/.local/lib/python3.6/site-packages/arctic/tickstore/tickstore.py:413: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(dtype, int):
# Completed querying 5600000 ['LTC-USD', 'tLTCUSD'] records in 8 seconds
#
# Splitting 5600000 records into 12 chunks... 466666 records/cpu
# Complete splitting pandas into chunks in 1 seconds.
# Completed. Process-0 dataframe.to_dict() in 12 seconds
# Completed. Process-1 dataframe.to_dict() in 10 seconds
# Completed. Process-2 dataframe.to_dict() in 13 seconds
# Completed. Process-3 dataframe.to_dict() in 14 seconds
# Completed. Process-4 dataframe.to_dict() in 16 seconds
# Completed. Process-5 dataframe.to_dict() in 18 seconds
# Completed. Process-6 dataframe.to_dict() in 19 seconds
# Completed. Process-7 dataframe.to_dict() in 19 seconds
# Completed. Process-8 dataframe.to_dict() in 20 seconds
# Completed. Process-9 dataframe.to_dict() in 22 seconds
# Completed. Process-10 dataframe.to_dict() in 21 seconds
# Completed. Process-11 dataframe.to_dict() in 23 seconds
# ***
# Completed get_tick_history() in 41 seconds
# ***

# %%
tick_history[1]
# Out:
# {'SYMBOL': 'tLTCUSD',
#  'size': 19.66,
#  'system_time': '2018-11-20 17:31:16.493021+00:00',
#  'side': 'buy',
#  'product_id': 'tLTCUSD',
#  'order_id': 19257430621.0,
#  'price': 35.118,
#  'type': 'preload',
#  'trade_id': nan,
#  'order_type': None,
#  'sequence': nan,
#  'taker_order_id': None,
#  'funds': None,
#  'time': None,
#  'maker_order_id': None,
#  'remaining_size': None,
#  'client_oid': None,
#  'reason': None}

# %%
coinbaseOrderBook = CoinbaseOrderBook(query['ccy'][0])
bitfinexOrderBook = BitfinexOrderBook(query['ccy'][1])

orderbook_snapshot_history = sim.get_orderbook_snapshot_history(coinbaseOrderBook, 
                                                                bitfinexOrderBook, 
                                                                tick_history[2000000:])
# Out:
# Starting get_orderbook_snapshot_history() with 3600000 ticks for LTC-USD and tLTCUSD
# ...completed 0 loops in 0 seconds
# sequence gap: LTC-USD missing 3047218121 messages. new_sequence: 3047218121 [done]
#
# LTC-USD first tick: 2018-11-20 22:04:14.172000+00:00 | Sequence: 3047218121
# ...completed 250000 loops in 8 seconds
# sequence gap: LTC-USD missing 97909 messages. new_sequence: 3047452639 [load_book]
#
# --Cleared LTC-USD order book--
# --Cleared tLTCUSD order book--
# ...completed 500000 loops in 14 seconds
# ...completed 750000 loops in 24 seconds
# ...completed 1000000 loops in 32 seconds
# ...completed 1250000 loops in 40 seconds
# ...completed 1500000 loops in 48 seconds
# --Cleared tLTCUSD order book--
# sequence gap: LTC-USD missing 783 messages. new_sequence: 3047897120 [load_book]
#
# --Cleared LTC-USD order book--
# ...completed 1750000 loops in 56 seconds
# ...completed 2000000 loops in 65 seconds
# ...completed 2250000 loops in 75 seconds
# --Cleared tLTCUSD order book--
# sequence gap: LTC-USD missing 787 messages. new_sequence: 3048181246 [load_book]
#
# --Cleared LTC-USD order book--
# ...completed 2500000 loops in 83 seconds
# ...completed 2750000 loops in 93 seconds
# ...completed 3000000 loops in 100 seconds
# ...completed 3250000 loops in 110 seconds
# ...completed 3500000 loops in 117 seconds
# Completed run_simulation() with 3600000 ticks in 121 seconds at 29752 ticks/second

# %%
normalized_data = sim.normalize_orderbook_snapshot_history(orderbook_snapshot_history)
# Out:
# ***
# Simulator.get_orderbook_snapshot_history_normalized() executed in 0 seconds
# ***

# %%
normalized_data.tail()
# Out:
#         coinbase_midpoint  midpoint_delta  coinbase-bid-notional-0  \
# 128042           0.494511         2.40222                -0.396911
# 128043           0.494511         2.40222                -0.396911
# 128044           0.494511         2.40222                -0.399208
# 128045           0.494511         2.40222                -0.400671
# 128046           0.494511         2.40222                -0.400671
#
#         coinbase-bid-notional-1  coinbase-bid-notional-2  \
# 128042                -0.535561                -0.387006
# 128043                -0.535561                -0.387006
# 128044                -0.537135                -0.388203
# 128045                -0.538137                -0.388964
# 128046                -0.157972                -0.542017
#
#         coinbase-bid-distance-0  coinbase-bid-distance-1  \
# 128042                -0.116677                -0.377969
# 128043                -0.116677                -0.377969
# 128044                -0.116677                -0.377969
# 128045                -0.116677                -0.377969
# 128046                -0.116677                 0.001034
#
#         coinbase-bid-distance-2  coinbase-ask-notional-0  \
# 128042                -0.585130                 0.456783
# 128043                -0.585130                 0.131720
# 128044                -0.585130                 0.131720
# 128045                -0.585130                 0.131720
# 128046                 0.179974                 0.131720
#
#         coinbase-ask-notional-1   ...    bitfinex-ask-notional-1  \
# 128042                 0.120567   ...                  -0.358226
# 128043                 0.120731   ...                  -0.358226
# 128044                 0.120731   ...                  -0.358226
# 128045                 0.120731   ...                  -0.358226
# 128046                 0.120731   ...                  -0.358226
#
#         bitfinex-ask-notional-2  bitfinex-ask-distance-0  \
# 128042                -0.392297                 0.273063
# 128043                -0.392297                 0.273063
# 128044                -0.392297                 0.273063
# 128045                -0.392297                 0.273063
# 128046                -0.392297                 0.273063
#
#         bitfinex-ask-distance-1  bitfinex-ask-distance-2  bitfinex-buys  \
# 128042                -0.276705                -0.487694      -0.044688
# 128043                -0.276705                -0.487694      -0.044688
# 128044                -0.276705                -0.487694      -0.044688
# 128045                -0.276705                -0.487694      -0.044688
# 128046                -0.276705                -0.487694      -0.044688
#
#         bitfinex-sells                                t   d       m
# 128042       -0.042599 2018-11-21 07:47:36.971000+00:00  21  32.295
# 128043       -0.042599 2018-11-21 07:47:37.382000+00:00  21  32.295
# 128044       -0.042599 2018-11-21 07:47:37.603000+00:00  21  32.295
# 128045       -0.042599 2018-11-21 07:47:37.753000+00:00  21  32.295
# 128046       -0.042599 2018-11-21 07:47:38.033000+00:00  21  32.295
#
# [5 rows x 33 columns]

# %%
orderbook_snapshot_history.head()
# Out:
#                         system_time  coinbase_midpoint  midpoint_delta  \
# 17 2018-11-20 22:04:18.784000+00:00             32.805         -1.5780
# 18 2018-11-20 22:04:18.945000+00:00             32.805         -1.5680
# 19 2018-11-20 22:04:19.188000+00:00             32.810         -1.5830
# 20 2018-11-20 22:04:19.439000+00:00             32.805         -1.5780
# 21 2018-11-20 22:04:19.705000+00:00             32.805         -1.5355
#
#     coinbase-bid-notional-0  coinbase-bid-notional-1  coinbase-bid-notional-2  \
# 17                1593.3200              1621.126092              3627.142555
# 18                1593.3200              1621.126092              3627.142555
# 19                1547.1042              1574.910292              3580.926755
# 20                1576.6685              1604.474592              3610.491055
# 21                1576.6685              1604.474592              3610.491055
#
#     coinbase-bid-distance-0  coinbase-bid-distance-1  coinbase-bid-distance-2  \
# 17                    0.155                    0.375                    1.105
# 18                    0.155                    0.375                    1.105
# 19                    0.150                    0.380                    1.110
# 20                    0.155                    0.375                    1.105
# 21                    0.155                    0.375                    1.105
#
#     coinbase-ask-notional-0       ...        bitfinex-bid-distance-1  \
# 17              1548.037082       ...                         0.0830
# 18              1548.037082       ...                         0.0260
# 19              1548.037082       ...                         0.1090
# 20              1548.037082       ...                         0.0990
# 21              2571.304170       ...                         0.0555
#
#     bitfinex-bid-distance-2  bitfinex-ask-notional-0  bitfinex-ask-notional-1  \
# 17                   0.0990                1411.1790                1480.0570
# 18                   0.0550                  13.7512                1424.9302
# 19                   0.1100                  68.8780                 759.1980
# 20                   0.1000                1411.1790                1480.0550
# 21                   0.0565                   6.8756                1416.4556
#
#     bitfinex-ask-notional-2  bitfinex-ask-distance-0  bitfinex-ask-distance-1  \
# 17              2481.772865                   0.0360                   0.0560
# 18              1493.808200                   0.0050                   0.0460
# 19              2267.455508                   0.0460                   0.1230
# 20              2483.517826                   0.0360                   0.0550
# 21              1485.333600                   0.0375                   0.0395
#
#     bitfinex-ask-distance-2  bitfinex-buys  bitfinex-sells
# 17                   0.0610            0.0             0.0
# 18                   0.0660            0.0             0.0
# 19                   0.1680            0.0             0.0
# 20                   0.1010            0.0             0.0
# 21                   0.0985            0.0             0.0
#
# [5 rows x 31 columns]

# %%
laggg = sim.append_lags(normalized_data, 2)
# Out:
# ***
# Simulator.append_lags() executed in 0 seconds
# ***

# %%
laggg[['coinbase_midpoint','t', 'd', 'm']].head(2)
# Out:
#     coinbase_midpoint                                t   d       m
# 19           2.251470 2018-11-20 22:04:19.188000+00:00  20  32.810
# 20           2.234413 2018-11-20 22:04:19.439000+00:00  20  32.805

# %%
data_transformed = orderbook_snapshot_history.iloc[80000:,:].copy()

# %%
fig, ax1 = plt.subplots(figsize=(20, 10))

color = 'tab:blue'
ax1.set_xlabel('Normalized Prices')
ax1.set_ylabel('Price', color=color)
ax1.plot(data_transformed['coinbase_midpoint'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:orange'
ax2.set_ylabel('Delta', color=color)  # we already handled the x-label with ax1
# ax2.plot(data_to_transform['coinbase-sells'].values, color=color)

total_buys = data_transformed['bitfinex-buys'].add(data_transformed['coinbase-buys'])
total_sells = data_transformed['bitfinex-sells'].add(data_transformed['coinbase-sells'])

minutes = 6
total_buys = total_buys.rolling(4*60*minutes).mean()
total_sells = total_sells.rolling(4*60*minutes).mean()

ax2.plot(total_buys, color='tab:green')
ax2.plot(total_sells, color='tab:red')

# ax2.plot(data_to_transform['bitfinex-sells'].values, color='tab:grey')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped

plt.show()

# %%
DEFAULT_ACTION_SET = (
    (1, 0, 0, 0, 0),  # 0. Buy
    (0, 1, 0, 0, 0),  # 1. Close-buy
    (0, 0, 1, 0, 0),  # 2. Short
    (0, 0, 0, 1, 0),  # 3. Cover-short
    (0, 0, 0, 0, 1),  # 4. Do nothing
)

# %%
len(DEFAULT_ACTION_SET)
# Out:
# 5

# %%
tmp = laggg.values

# %%
tmp.shape
# Out:
# (128028, 93)

# %%
helpers = (True, False)

# %%
np.concatenate((tmp[0], helpers))
# Out:
# array([2.2514704732556328, -0.6933741770902185, -0.4151010835103822,
#        -0.7823109244686105, -0.8191909187932135, 8.915750604560339,
#        12.697645766038773, 26.576063703701976, -0.6314488453284338,
#        -0.7204588910276662, -0.949335121671143, 8.915750604559872,
#        5.150565873536536, 7.377152979856538, -0.05817565715745836,
#        -0.053724151175709785, -0.20767433381253797, 0.04472757044681575,
#        -0.086024020599771, 1.0537353033808714, 2.5115821563019325,
#        2.071912621795505, -0.29217136023007734, -0.30803277718354516,
#        -0.2514821516249455, 1.053735303380865, 3.193310198036525,
#        4.034760696606995, -0.044687505423267694, -0.04259861574047062,
#        Timestamp('2018-11-20 22:04:19.188000+0000', tz='UTC'), 20, 32.81,
#        2.2344126097008856, -0.5251353594654921, -0.40513168840989583,
#        -0.7754803626919461, -0.8140011946920449, 9.250284967571185,
#        12.50814409616822, 26.448546361586857, -0.6314488453284338,
#        -0.7204588910276662, -0.949335121671143, 9.250284967571194,
#        5.355545817127319, 7.543695163877007, -0.05817565715745836,
#        -0.053724151175709785, -0.043005051938226055, -0.08460863352055,
#        -0.14614849753559317, -0.4011539861663378, -0.1892872653656773,
#        0.39787691360726757, -0.29851999907749427, -0.24474077205154646,
#        -0.322605136282527, -0.4011539861665854, 0.466870078075542,
#        0.6920769895745102, -0.044687505423267694, -0.04259861574047062,
#        2.2344126097008856, -0.6372945712152566, -0.40513168840989583,
#        -0.7754803626919461, -0.8140011946920449, 9.250284967571185,
#        12.50814409616822, 26.448546361586857, -0.6314488453284338,
#        -0.7204588910276662, -0.949335121671143, 9.250284967571194,
#        5.355545817127319, 7.543695163877007, -0.05817565715745836,
#        -0.053724151175709785, 0.13291859105050374, -0.04599407381838723,
#        0.1251752754431768, 0.6988842571496356, 1.6655266748155677,
#        1.737105480157728, -0.13758621700524643, -0.23949979721435116,
#        -0.231779517264802, 0.698884257149884, 0.8209532105384156,
#        0.5282199451125217, -0.044687505423267694, -0.04259861574047062,
#        True, False], dtype=object)

# %%
counter = 0
for i in laggg.columns.tolist():
    counter += 1
    if i == 'm':
        print(counter)
# Out:
# 33

# %%
for i in range(tmp.shape[0]):
    if i < 10:
        print('exiting')
        print(tmp[i].reshape(1,-1).shape)
        break
# Out:
# exiting
# (1, 93)

# %%
len(sim.get_feature_labels(False))
# Out:
# 30
